# %% [markdown]
# # Data Folder
#
# This folder is **git-ignored** — large/raw files are **not** stored in the repository.
#
# ## How to get the data
#
# 1. Download **freMTPL2freq.csv** and **freMTPL2sev.csv** from:
#    - Kaggle: https://www.kaggle.com/datasets/floser/french-motor-claims-datasets-fremtpl2freq
#    - or https://www.kaggle.com/datasets/floser/fremtpl2sev
#
# 2. Place them in `data/raw/`
#
# 3. (optional) Create `data/processed/` for cleaned/merged versions during analysis.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("karansarpal/fremtpl2-french-motor-tpl-insurance-claims")

print("Path to dataset files:", path)
